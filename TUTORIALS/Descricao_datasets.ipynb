# %% [markdown]
# #Conjuntos de dados usados nos experimentos da tese de doutorado

# %%
# !pip install --quiet git+https://github.com/PatriciaLucas/AutoML.git
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
import pandas as pd
import numpy as np
from MARTS import datasets
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
import math
from matplotlib.collections import PolyCollection

# %%
def print_autocorrelation(data, figsize):
  num_plots = data.shape[1]
  num_cols = 3
  num_rows = math.ceil(num_plots / num_cols)

  fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)

  for i, column in enumerate(data.columns):
      row = i // num_cols
      col = i % num_cols
      plot_acf(data[column], ax=axes[row, col], color='black', vlines_kwargs={"colors": 'black'})
      axes[row, col].set_title(f'{column}')
      for item in axes[row, col].collections:
        if type(item)==PolyCollection:
            item.set_facecolor('black')

  for j in range(num_plots, num_rows * num_cols):
      fig.delaxes(axes.flatten()[j])

  plt.tight_layout()
  plt.show()

# %% [markdown]
# #Conjuntos de dados de domínio econômico

# %% [markdown]
# ###Descrição geral
# Os conjuntos de dados ECONOMICO\_1, ECONOMICO\_2, ECONOMICO\_3, ECONOMICO\_4 e ECONOMICO\_5 são usados para prever os índices médios diários que reflete aproximadamente a situação de mercados financeiros. Além do índice médio, outras variáveis são o preço de abertura, máxima, mínima, fechamento e o volume de negociações para cada dia útil.
#
# | Base de dados | Granularidade | Número de amostras | Número de variáveis | Alvo                                 |
# |---------------|---------------|--------------------|---------------------|--------------------------------------|
# | ECONOMICO_1   | dia           | 2,970              | 6                   | AVG: Índice médio de Bitcoin para USD     |
# | ECONOMICO_2   | dia           | 8,469              | 6                   | AVG: Índice médio Dow Jones               |
# | ECONOMICO_3   | dia           | 5,496              | 6                   | AVG: Índice médio do mercado FOREX EUR-GBP|
# | ECONOMICO_4   | dia           | 5,496              | 6                   | AVG: Índice médio do mercado FOREX EUR-USD|
# | ECONOMICO_5   | dia           | 5,496              | 6                   | AVG: Índice médio do mercado FOREX GBP-USD|

# %% [markdown]
# ###ECONOMICO_1
#
# Fonte: [link para download](https://query.data.world/s/72gews5w3c7oaf7by5vp7evsasluia)

# %%
data = datasets.get_multivariate('ECONOMICS_1')
data.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   2960.000000   2960.000000   2960.000000   2960.000000  2.960000e+03
# mean    1381.630958   1431.532988   1324.157715   1383.972194  1.428511e+08
# std     2910.877629   3028.513773   2762.818332   2912.553940  4.177715e+08
# min        0.049510      0.049510      0.010000      0.049510  0.000000e+00
# 25%       11.437500     11.790000     10.942500     11.495000  4.269158e+05
# 50%      282.414994    290.264999    274.375000    282.625000  8.026490e+06
# 75%      704.342515    720.897506    679.477509    704.770005  3.364020e+07
# max    19346.599609  19870.619141  18750.910156  19345.490234  6.245732e+09
#
#                 AVG
# count   2960.000000
# mean    1380.323464
# std     2902.084413
# min        0.049510
# 25%       11.453125
# 50%      282.834996
# 75%      703.273121
# max    19258.459961

# %%
print_autocorrelation(data)

# %%
plt.plot(data['AVG'], color='black')
plt.title('ECONOMICO_1')
plt.xticks([])
plt.ylabel('Índice médio - AVG')
plt.show()

# %% [markdown]
# ###ECONOMICO_2
#
# Fonte: [link para download](https://query.data.world/s/d4hfir3xrelkx33o3bfs5dbhyiztml)

# %%
data = datasets.get_multivariate('ECONOMICS_2')
data.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   8468.000000   8468.000000   8468.000000   8468.000000  8.468000e+03
# mean    9182.662143   9238.919400   9125.196436   9185.424558  1.329193e+08
# std     5724.709294   5747.547731   5701.105428   5725.670572  1.168859e+08
# min     1243.709961   1251.209961   1235.530029   1242.050049  2.530000e+06
# 25%     3511.474976   3523.210022   3494.702515   3511.859925  2.575750e+07
# 50%     9745.334961   9814.385254   9679.064942   9748.049804  9.834000e+07
# 75%    12222.515381  12289.429688  12145.954834  12226.414795  2.194125e+08
# max    26584.279297  26616.710938  26435.339844  26616.710938  8.239400e+08
#
#                 AVG
# count   8468.000000
# mean    9183.050634
# std     5724.553823
# min     1243.345001
# 25%     3510.981857
# 50%     9754.267578
# 75%    12225.999451
# max    26531.377930

# %%
print_autocorrelation(data)

# %%
plt.plot(data['AVG'], color='black')
plt.title('ECONOMICO_2')
plt.xticks([])
plt.ylabel('Índice médio - AVG')
plt.show()

# %% [markdown]
# ###ECONOMICO_3
#
# Fonte: [link para download](https://query.data.world/s/gvsaeruthnxjkwzl7z4ki7u5rduah3)

# %%
data = datasets.get_multivariate('ECONOMICS_3')
data.describe()
# Out:
#              open         high          low        close          AVG
# count  5494.00000  5494.000000  5494.000000  5494.000000  5494.000000
# mean      0.76742     0.769995     0.764982     0.767420     0.767454
# std       0.09305     0.093698     0.092463     0.093052     0.093051
# min       0.59600     0.596900     0.595400     0.596000     0.596600
# 25%       0.68250     0.683825     0.681100     0.682500     0.682356
# 50%       0.78615     0.789200     0.783450     0.786150     0.786338
# 75%       0.85365     0.857100     0.850800     0.853575     0.853725
# max       0.97770     0.980100     0.967500     0.977400     0.971850

# %%
print_autocorrelation(data)

# %%
plt.plot(data['AVG'], color='black')
plt.title('ECONOMICO_3')
plt.xticks([])
plt.ylabel('Índice médio - AVG')
plt.show()

# %% [markdown]
# ###ECONOMICO_4
#
# Fonte: [link para download](https://query.data.world/s/od4eojioz4w6o5bbwxjfn6j5zoqtos)

# %%
data = datasets.get_multivariate('ECONOMICS_4')
data.describe()
# Out:
#               open         high          low        close          AVG
# count  5494.000000  5494.000000  5494.000000  5494.000000  5494.000000
# mean      1.231675     1.236468     1.226950     1.231675     1.231692
# std       0.160110     0.160686     0.159440     0.160112     0.160059
# min       0.836500     0.847000     0.835000     0.836600     0.838900
# 25%       1.126300     1.130700     1.121525     1.126325     1.126156
# 50%       1.253500     1.258900     1.249550     1.253400     1.253775
# 75%       1.343700     1.347600     1.338675     1.343775     1.343831
# max       1.597200     1.603600     1.590100     1.597200     1.594975

# %%
print_autocorrelation(data)

# %%
plt.plot(data['AVG'], color='black')
plt.title('ECONOMICO_4')
plt.xticks([])
plt.ylabel('Índice médio - AVG')
plt.show()

# %% [markdown]
# ###ECONOMICO_5
#
# Fonte: [link para download](https://query.data.world/s/sw4mijpowb3mqv6bsat7cdj54hyxix)

# %%
data = datasets.get_multivariate('ECONOMICS_5')
data.describe()
# Out:
#               open         high          low        close          AVG
# count  5494.000000  5494.000000  5494.000000  5494.000000  5494.000000
# mean      1.614370     1.620094     1.608519     1.614367     1.614337
# std       0.200131     0.200527     0.199868     0.200130     0.200129
# min       1.201900     1.204700     1.197600     1.201900     1.203325
# 25%       1.473325     1.480000     1.465950     1.473300     1.472919
# 50%       1.588300     1.593450     1.583150     1.588400     1.588125
# 75%       1.755100     1.761925     1.750175     1.755100     1.756487
# max       2.107700     2.115800     2.098200     2.107700     2.104775

# %%
print_autocorrelation(data)

# %%
plt.plot(data['AVG'], color='black')
plt.title('ECONOMICO_1')
plt.xticks([])
plt.ylabel('Índice médio - AVG')
plt.xlabel('Amostras diárias de 2010 a 2018')
plt.show()

# %% [markdown]
# #Conjunto de dados de domínio Energético

# %% [markdown]
# ###Descrição geral
# Os conjuntos de dados ENERGIA\_1, ENERGIA\_2, ENERGIA\_3, ENERGIA\_4 e ENERGIA\_5 são usados para prever produção, consumo e preço de energia solar, elétrica e eólica.
#
#
# | Base de dados  | Granularidade | Número de amostras | Número de variáveis | Alvo                           |
# |----------------|---------------|--------------------|---------------------|--------------------------------|
# | ENERGIA_1      | hora          | 43,802             | 9                   | **Power**: Produção de energia eólica     |
# | ENERGIA_2      | hora          | 35,003             | 24                  | **total load actual**: Consumo de energia elétrica     |
# | ENERGIA_3      | hora          | 35,003             | 24                  | **generation solar**: Solar energy consumption        |
# | ENERGIA_4      | hora          | 35,003             | 24                  | **generation wind onshore**: Consumo de energia solar        |
# | ENERGIA_5      | hora          | 35,003             | 24                  | **price actual**: Preço da energia elétrica       |

# %% [markdown]
# ###ENERGIA_1
#
# Fonte: [link para download](https://www.kaggle.com/datasets/mubashirrahim/wind-power-generation-data-forecasting)

# %%
data = datasets.get_multivariate('ENERGY_1')
data.describe()
# Out:
#        temperature_2m  relativehumidity_2m   dewpoint_2m  windspeed_10m  \
# count    43800.000000         43800.000000  43800.000000   43800.000000
# mean        47.862911            72.288744     38.569308       3.591147
# std         19.453691            16.852287     18.772110       1.649318
# min        -14.400000            18.000000    -17.100000       0.000000
# 25%         32.100000            60.000000     24.300000       2.410000
# 50%         47.300000            74.000000     38.100000       3.300000
# 75%         64.500000            86.000000     54.700000       4.590000
# max         94.100000           100.000000     76.300000      13.450000
#
#        windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# count    43800.000000       43800.000000        43800.000000   43800.000000
# mean         6.284431         203.637329          203.343676       7.771795
# std          2.685216          96.371262           97.959852       3.569147
# ...

# %%
print_autocorrelation(data, (15, 5))

# %% [markdown]
# ###ENERGIA_2, ENERGIA_3, ENERGIA_4 e ENERGIA_5
#
# Fonte: [link para download](https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather/data)

# %%
data = datasets.get_multivariate('ENERGY_2')
data.iloc[:,0:10].describe()
# Out:
#        generation biomass  generation fossil brown coal/lignite  \
# count        35000.000000                          35000.000000
# mean           383.711229                            448.913943
# std             85.318996                            354.423808
# min              0.000000                              0.000000
# 25%            333.000000                              0.000000
# 50%            367.000000                            510.000000
# 75%            434.000000                            758.000000
# max            592.000000                            999.000000
#
#        generation fossil gas  generation fossil hard coal  \
# count           35000.000000                 35000.000000
# mean             5622.767443                  4260.898729
# std              2203.304154                  1961.026798
# min                 0.000000                     0.000000
# 25%              4125.000000                  2538.000000
# ...

# %%
data.iloc[:,10:].describe()
# Out:
#        generation other renewable  generation solar  generation waste  \
# count                35000.000000      35000.000000      35000.000000
# mean                    85.613086       1433.452757        269.354143
# std                     14.080219       1680.332574         50.239617
# min                      0.000000          0.000000          0.000000
# 25%                     73.000000         71.000000        240.000000
# 50%                     88.000000        616.000000        279.000000
# 75%                     97.000000       2579.000000        310.000000
# max                    119.000000       5792.000000        357.000000
#
#        generation wind onshore  total load actual  price actual          temp  \
# count             35000.000000       35000.000000  35000.000000  35000.000000
# mean               5466.140271       28702.563871     57.868874    290.814039
# std                3215.635740        4576.763403     14.210092      7.221782
# ...

# %%
print_autocorrelation(data, (20, 10))

# %% [markdown]
# #Conjuntos de dados de domínio IOT

# %% [markdown]
# ###Descrição geral
# Os conjuntos de dados IOT\_1, IOT\_2, IOT\_3, IOT\_4 e IOT\_5 são usados para prever o consumo de energia por eletrodomésticos e a qualidade do ar.
#
#
# | Base de dados | Granularidade | Número de amostras | Número de variáveis | Alvo                                   |
# |---------------|---------------|--------------------|---------------------|----------------------------------------|
# | IOT_1         | minuto        | 605,261            | 18                  | **active_power**: Consumo de energia por eletrodomésticos |
# | IOT_2         | minuto        | 503,911            | 28                  | **use**: Consumo de energia por eletrodomésticos |
# | IOT_3         | minuto        | 19,735             | 27                  | **Appliances**: Consumo de energia por eletrodomésticos |
# | IOT_4         | hora          | 751,039            | 13                  | **CO**: Qualidade do ar                        |
# | IOT_5         | hora          | 35,052             | 10                  | **PM2.5**: Qualidade do ar                        |

# %% [markdown]
# ###IOT_1
#
# Fonte: [link para download](https://www.sciencedirect.com/science/article/pii/S2352340924004219)

# %%
data = datasets.get_multivariate('IOT_1')
data.describe()
# Out:
#         active_power        current        voltage  reactive_power  \
# count  605260.000000  605260.000000  605260.000000   605260.000000
# mean      286.019377       2.587303     125.417300      132.538007
# std       189.545683       1.591395       4.390612       71.030254
# min        24.400000       0.300000     107.600000        4.730000
# 25%       159.800000       1.610000     122.600000       74.070000
# 50%       250.300000       2.290000     124.400000      128.500000
# 75%       365.400000       3.220000     129.500000      177.652500
# max      2900.000000      24.410000     135.500000     1293.580000
#
#        apparent_power   power_factor           temp     feels_like  \
# count   605260.000000  605260.000000  605260.000000  605260.000000
# mean       321.839271       0.854202      19.525256      18.712625
# std        191.743962       0.114629       6.607351       6.722516
# min         37.140000       0.201800      -5.560000      -6.130000
# ...

# %%
print_autocorrelation(data, (20, 10))

# %% [markdown]
# ###IOT_2
#
# Fonte: [link para download](https://www.kaggle.com/datasets/taranvee/smart-home-dataset-with-weather-information)

# %%
data = datasets.get_multivariate('IOT_2')
data.describe()
# Out:
#                  use            gen     Dishwasher      Furnace 1  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.981937       0.066339       0.034696       0.200955
# std         0.693238       0.128956       0.200537       0.213772
# min         0.000033       0.000000       0.000000       0.002433
# 25%         0.493967       0.003067       0.000017       0.020800
# 50%         0.858683       0.003383       0.000050       0.070867
# 75%         1.294375       0.046367       0.000233       0.465917
# max         7.854933       0.581533       1.378650       1.915517
#
#            Furnace 2    Home office         Fridge    Wine cellar  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.230495       0.077525       0.053941       0.020436
# std         0.245636       0.095604       0.071234       0.036447
# min         0.002017       0.002467       0.000133       0.000217
# ...

# %%
data.shape
# Out:
# (100000, 27)

# %%
print_autocorrelation(data, (15, 5))

# %% [markdown]
# ###IOT_3
#
# Fonte: [link para download](https://archive.ics.uci.edu/dataset/374/appliances+energy+prediction)

# %%
data = datasets.get_multivariate('IOT_3')
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
data.shape
# Out:
# (19735, 28)

# %%
print_autocorrelation(data, (15, 5))
# Out:
# <ipython-input-3-78eb9f25aca5>:20: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ###IOT_4
#
# Fonte: [link para download](https://www.kaggle.com/datasets/fedesoriano/air-quality-data-set)

# %%
data = datasets.get_multivariate('IOT_4')
data.describe()
# Out:
#                 CO      PT08.S1         C6H6      PT08.S2          NOx  \
# count  9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean    -34.207524  1048.990061     1.865683   894.595276   168.616971
# std      77.657170   329.832710    41.380206   342.333252   257.433866
# min    -200.000000  -200.000000  -200.000000  -200.000000  -200.000000
# 25%       0.600000   921.000000     4.000000   711.000000    50.000000
# 50%       1.500000  1053.000000     7.900000   895.000000   141.000000
# 75%       2.600000  1221.000000    13.600000  1105.000000   284.000000
# max      11.900000  2040.000000    63.700000  2214.000000  1479.000000
#
#            PT08.S3          NO2      PT08.S4      PT08.S5            T  \
# count  9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean    794.990168    58.148873  1391.479641   975.072032    18.317829
# std     321.993552   126.940455   467.210125   456.938184     8.657639
# ...

# %%
print_autocorrelation(data, (15, 5))

# %% [markdown]
# ###IOT_5
#
# Fonte: [link para download](https://archive.ics.uci.edu/dataset/501/beijing+multi+site+air+quality+data)

# %%
data = datasets.get_multivariate('IOT_5')
data.describe()
# Out:
#               PM2.5           SO2           NO2            CO            O3  \
# count  35052.000000  35052.000000  35052.000000  35052.000000  35052.000000
# mean      83.155536     18.622815     63.216928   1266.886654     61.485083
# std       82.310146     28.876910     63.562034   1242.091378     78.905547
# min       -0.675900     -0.677000     -0.375302    100.000000     -0.881935
# 25%       22.000000      3.000000     30.000000    500.000000      7.000000
# 50%       60.000000      9.000000     54.000000    900.000000     43.000000
# 75%      114.000000     23.000000     82.000000   1600.000000     84.000000
# max      898.000000    936.768000    997.758000  10000.000000    987.462000
#
#                TEMP          PRES          DEWP          RAIN          WSPM
# count  35052.000000  35052.000000  35052.000000  35052.000000  35052.000000
# mean      13.587241   1011.847517      3.124860      0.067441      1.708584
# ...

# %%
print_autocorrelation(data, (15, 5))

# %% [markdown]
# #Conjuntos de dados de domínio clima

# %% [markdown]
# ###Descrição geral
# Os conjuntos de dados CLIMATICO\_1, CLIMATICO\_2 e CLIMATICO\_3 são usados para prever o radiação global, evapotranspiração e vazão do rio Xingu.
#
# | Base de dados | Granularidade | Número de amostras | Número de variáveis | Alvo                |
# |---------------|---------------|--------------------|---------------------|---------------------|
# | CLIMATICO_1   | hora          | 57,240             | 12                  | **glo_avg**: Radiação global     |
# | CLIMATICO_2   | dia           | 7,307              | 7                   | **ETO**: Evapotranspiração   |
# | CLIMATICO_3   | mês           | 492                | 19                  | **maxima**: Vazão do Rio Xingu  |

# %% [markdown]
# ###CLIMATICO_1
#
# Fonte: [link para download](https://github.com/petroniocandido/pyFTS/raw/8f20f3634aa6a8f58083bdcd1bbf93795e6ed767/pyFTS/data/SONDA_BSB.csv.bz2)

# %%
data = datasets.get_multivariate('CLIMATIC_1')
data.describe()
# Out:
#             glo_avg       dir_avg      diff_avg        lw_avg       par_avg  \
# count  57238.000000  5.723800e+04  5.723800e+04  5.723800e+04  5.723800e+04
# mean     505.314669 -2.637712e+15  3.268122e+15  3.474834e+15 -2.591406e+15
# std     3625.302241  9.969644e+15  8.724713e+15  7.815541e+15  8.804887e+15
# min    -4098.000000 -7.573716e+16 -4.918894e+16  3.322000e+03 -8.179563e+16
# 25%    -2518.000000 -1.987851e+15 -9.120000e+02  3.815000e+03 -1.328636e+15
# 50%    -1084.000000 -2.040000e+02  2.531500e+03  3.959000e+03  0.000000e+00
# 75%     2928.000000  1.805000e+03  3.303116e+15  3.495165e+15  5.029000e+03
# max    14880.000000  7.970994e+16  7.524747e+16  5.119404e+16  7.883658e+16
#
#             lux_avg        tp_sfc         humid         press          rain  \
# count  5.723800e+04  5.723800e+04  5.723800e+04  5.723800e+04  57238.000000
# mean  -2.966284e+15  3.754885e+15 -2.449505e+15  2.524883e+15      0.003203
# ...

# %%
print_autocorrelation(data, (20, 10))

# %% [markdown]
# ###CLIMATICO_2
#
# Fonte: POWER (Prediction Of Worldwide Energy Resources) da National Aeronautics and Space tion (NASA) e do satélite Chirps (Climate Hazards Group InfraRed Precipitation.

# %%
data = datasets.get_multivariate('CLIMATIC_2')
data.describe()
# Out:
#                 Rs           u2         Tmax         Tmin           RH  \
# count  7305.000000  7305.000000  7305.000000  7305.000000  7305.000000
# mean     19.020862     1.443203    32.033949    24.095003    81.090089
# std       4.385476     0.708328     1.724842     0.823297     5.745403
# min       5.000000     0.000000    24.700000    20.500000    67.600000
# 25%      15.900000     0.900000    31.100000    23.600000    76.300000
# 50%      19.900000     1.400000    32.300000    24.100000    81.100000
# 75%      22.700000     2.000000    33.200000    24.600000    85.700000
# max      26.200000     3.800000    38.600000    27.600000    96.000000
#
#                 pr          ETO
# count  7305.000000  7305.000000
# mean      6.559329     4.234114
# std       8.817729     1.033220
# min       0.000000     1.300000
# 25%       0.000000     3.500000
# 50%       3.300000     4.300000
# 75%       9.700000     5.100000
# max      98.200000     6.300000

# %%
print_autocorrelation(data, (15, 5))

# %% [markdown]
# ###CLIMATICO_3
#
# Fonte: Banco de dados hidrometeorológicos da Agência Nacional de Águas (ANA).

# %%
data = datasets.get_multivariate('CLIMATIC_3')
data = data.interpolate()
data.describe()
# Out:
#            maxima     nino1_2       nino3       nino4     nino3_4  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000
# mean   502.063008   23.436382   26.117236   28.688577   27.190000
# std    178.826111    2.231788    1.231943    0.628953    0.934867
# min    237.000000   19.450000   23.630000   26.810000   24.810000
# 25%    331.250000   21.495000   25.140000   28.250000   26.507500
# 50%    493.400000   23.240000   26.065000   28.745000   27.200000
# 75%    673.500000   25.440000   27.090000   29.160000   27.802500
# max    886.000000   29.120000   29.240000   30.300000   29.600000
#
#        altantico_norte  altantico_sul  atlantico_tropical  pressao_darwin  \
# count       492.000000     492.000000          492.000000      492.000000
# mean         26.860874      24.968598           27.835386     1010.179472
# std           0.989458       1.518813            0.537858        2.690128
# min          24.790000      22.280000           26.770000     1003.500000
# ...

# %%
print_autocorrelation(data, (20, 10))
